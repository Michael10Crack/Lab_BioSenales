# %% [markdown]
# Como subir los commits?

# %%
# mi repositorio
# https://github.com/Michael10Crack/Lab_BioSenales.git

# %%
#   por comando (en terminal)
#   git clone _______ (carpeta a clonar)
#   cd.. para salir de la ultima carpeta
#   cd *nombre de la carpeta* (la carpeta a la que quiero entrar) [con tabulador me rellena el nombre de la carpeta]
#   ls -> para ver todas las carpetas
#   git add . -> para subir 
#   git add (nombre del archivo) para solo un archivo
#   git commit -m "Comentario"
#   git push -> para enviarlo ahora sí
#   git pull -> para bajar el archivo
